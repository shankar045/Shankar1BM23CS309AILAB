# %% [markdown]
# <a href="https://colab.research.google.com/github/shankar045/Shankar1BM23CS309AILAB/blob/main/kab%207%20Unification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def unify(x, y, subs=None):
    if subs is None:
        subs = {}

    if isinstance(x, str) and x in subs:
        return unify(subs[x], y, subs)
    if isinstance(y, str) and y in subs:
        return unify(x, subs[y], subs)

    if x == y:
        return subs
    if isinstance(x, str) and x.isupper():
        subs[x] = y
        return subs

    if isinstance(y, str) and y.isupper():
        subs[y] = x
        return subs

    if isinstance(x, tuple) and isinstance(y, tuple):
        if x[0] != y[0] or len(x[1]) != len(y[1]):
            return None
        for a, b in zip(x[1], y[1]):
            subs = unify(a, b, subs)
            if subs is None:
                return None
        return subs


    return None


expr1 = ('p', ['b', 'X', ('f', [('g', ['Z'])])])
expr2 = ('p', ['Z', ('f', ['Y']), ('f', ['Y'])])

mgu = unify(expr1, expr2)
print("Most General Unifier (MGU):", mgu)
# Out:
# Most General Unifier (MGU): {'Z': 'b', 'X': ('f', ['Y']), 'Y': ('g', ['Z'])}
